# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")

# %%
df=pd.read_csv(".\dataset\India-Tourism-Statistics-1981-2020-fta_nri_ita.csv")
fta_nri_ita=df.copy()
fta_nri_ita.head()
# Out:
#    Year  FTAs in India (in million)  %- change over previous year  \
# 0  1981                        1.28                           2.0
# 1  1991                        1.68                          -1.7
# 2  2001                        2.54                          -4.2
# 3  2002                        2.38                          -6.0
# 4  2003                        2.73                          14.3
#
#    NRIs arrivals in India (in million)  %- change over the previous year  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                  NaN                               NaN
#
#    ITAs in India  (in million)  %- change over the previous year.1
# 0                          NaN                                 NaN
# 1                          NaN                                 NaN
# 2                          NaN                                 NaN
# 3                          NaN                                 NaN
# 4                          NaN                                 NaN

# %%
fta_nri_ita.rename(columns={'FTAs in India (in million)': 'FTA','NRIs arrivals in India (in million)':'NRI','ITAs in India  (in million)':'ITA'},inplace=True, errors='raise')
fta_nri_ita.drop(fta_nri_ita.iloc[:,2::2],axis=1,inplace=True)
fta_nri_ita.head()
# Out:
#    Year   FTA  NRI  ITA
# 0  1981  1.28  NaN  NaN
# 1  1991  1.68  NaN  NaN
# 2  2001  2.54  NaN  NaN
# 3  2002  2.38  NaN  NaN
# 4  2003  2.73  NaN  NaN

# %%
df=pd.melt(fta_nri_ita,['Year']).rename(columns={'variable':'Tourists'})

plt.figure(figsize=(20,8))
sns.set_context("talk")

g=sns.lineplot(x='Year', y='value', hue='Tourists', data=df)

g.set(xlabel="Year",ylabel="Number of tourists (in millions)", title="International Tourists To India [1981-2020]")
plt.xticks(
    range(1981,2021),
    rotation=45,
#     horizontalalignment='right',
    fontweight='light'
)
plt.plot()
# Out:
# []

# %%
quaterly=pd.read_csv(".\dataset\India-Tourism-Statistics-2001-2019-quaterly.csv").copy()
quaterly.head()
# Out:
#    Year  Arrivals  % Distribution by Quarter - 1st Quarter (Jan-Mar)  \
# 0  2001   2537282                                               31.3
# 1  2002   2384364                                               28.8
# 2  2003   2726214                                               27.7
# 3  2004   3457477                                               27.8
# 4  2005   3918610                                               28.3
#
#    % Distribution by Quarter - 2nd Quarter(Apr-June)  \
# 0                                               20.2
# 1                                               18.4
# 2                                               17.6
# 3                                               18.3
# 4                                               18.4
#
#    % Distribution by Quarter - 3rd Quarter (July-Sep)  \
# 0                                               23.0
# 1                                               21.1
# 2                                               22.8
# 3                                               21.8
# 4                                               21.4
#
#    % Distribution by Quarter - 4th Quarter (Oct-Dec)
# 0                                               25.5
# 1                                               31.7
# 2                                               31.9
# 3                                               32.1
# 4                                               31.9

# %%
tot_arrivals=quaterly[['Year','Arrivals']]
tot_arrivals.head()
# Out:
#    Year  Arrivals
# 0  2001   2537282
# 1  2002   2384364
# 2  2003   2726214
# 3  2004   3457477
# 4  2005   3918610

# %%
country_and_reason=pd.read_csv(".\dataset\India-Tourism-Statistics-2019_region-and-reason.csv")
country_and_reason.head()
# Out:
#                     Region Country of Nationality  Arrivals (in numbers)  \
# 0            North America                 CANADA                 351859
# 1            North America          UNITED STATES                1512032
# 2            North America                 OTHERS                      1
# 3            North America                  Total                1863892
# 4  Central & South America              ARGENTINA                  12844
#
#    Business and Professional(%)  Leisure Holiday and Recreation(%)  \
# 0                          4.82                              50.94
# 1                         11.24                              38.56
# 2                          0.00                             100.00
# 3                         10.03                              40.90
# 4                         14.69                              78.60
#
#    Medical(%)  Indian Diaspora(%)  Others(%)
# 0        0.14               21.49      22.61
# 1        0.08               29.48      20.64
# 2        0.00                0.00       0.00
# 3        0.09               27.97      21.01
# 4        0.08                1.25       5.38

# %%
agegroup=pd.read_csv(".\dataset\India-Tourism-Statistics-2020-agegroup.csv")
agegroup.head()
# Out:
#    Year     FTAs  % distribution by Age-Group (in Year) - 0-14  \
# 0  2001  2537282                                           7.0
# 1  2002  2384364                                           9.2
# 2  2003  2726214                                           7.2
# 3  2004  3457477                                           8.5
# 4  2005  3918610                                           8.6
#
#    % distribution by Age-Group (in Year) - 15-24  \
# 0                                           10.8
# 1                                           10.0
# 2                                           10.0
# 3                                            9.8
# 4                                            9.6
#
#    % distribution by Age-Group (in Year) - 25-34  \
# 0                                           20.1
# 1                                           19.4
# 2                                           19.5
# 3                                           18.8
# 4                                           18.8
#
#    % distribution by Age-Group (in Year) - 35-44  \
# 0                                           21.1
# 1                                           21.6
# 2                                           21.6
# 3                                           21.3
# 4                                           21.3
#
#    % distribution by Age-Group (in Year) - 45-54  \
# 0                                           19.4
# 1                                           19.4
# 2                                           19.4
# 3                                           19.4
# 4                                           19.5
#
#    % distribution by Age-Group (in Year) - 55-64  \
# 0                                           11.9
# 1                                           11.5
# 2                                           11.5
# 3                                           12.8
# 4                                           13.0
#
#    % distribution by Age-Group (in Year) - 65 and above  \
# 0                                                6.7
# 1                                                7.7
# 2                                                7.7
# 3                                                8.2
# 4                                                8.7
#
#    % distribution by Age-Group (in Year) - Not Reported
# 0                                                3.0
# 1                                                1.2
# 2                                                3.1
# 3                                                0.2
# 4                                                0.5

# %%
country_and_share=pd.read_csv(".\dataset\India-Tourism-Statistics-region-2017-2019.csv")
country_and_share.head()
# Out:
#                       Region Country of Nationality  \
# 0              North America                 Canada
# 1              North America                  U.S.A
# 2              North America                 Others
# 3              North America                  Total
# 4  Central and South America              Argentina
#
#    Number of Arrivals - 2017  Number of Arrivals - 2018  \
# 0                   335439.0                   351040.0
# 1                  1376919.0                  1456678.0
# 2                        NaN                        NaN
# 3                  1712358.0                  1807718.0
# 4                    14875.0                    16345.0
#
#    Number of Arrivals - 2019  Percentage Share - 2017  \
# 0                     351859                     3.34
# 1                    1512032                    13.72
# 2                          1                      NaN
# 3                    1863892                    17.06
# 4                      12844                     0.15
#
#    Percentage Share - 2018  Percentage Share - 2019  \
# 0                     3.32                     3.22
# 1                    13.80                    13.83
# 2                      NaN                      NaN
# 3                    17.12                    17.05
# 4                     0.15                     0.12
#
#    Percentage Change - 2018/17  Percentage Change - 2019/18
# 0                          4.7                          0.2
# 1                          5.8                          3.8
# 2                          NaN                          NaN
# 3                          5.6                          3.1
# 4                          9.9                        -21.4

# %%
statewise_data=pd.read_csv(".\dataset\India-Tourism-Statistics-statewise_2019-2020_domestic_foreign.csv")
statewise_data.head()
# Out:
#   S. No.          States/UTs  Domestic -2019  Foreign - 2019  Domestic -2020  \
# 0      1         A&N Island           505398           16206          191207
# 1      2    Andhra Pradesh         237051508          280356        70828590
# 2      3  Arunachal Pradesh           555639            7825           42871
# 3      4              Assam          5447805           26878         1266898
# 4      5             Bihar          33990038         1093141         5638024
#
#    Foreign - 2020 Growth rate - DTV  2020/19 Growth rate - FTV 2020/19
# 0            5412                     -62.17                     -66.6
# 1           67591                     -70.12                    -75.89
# 2             961                     -92.28                    -87.72
# 3            7285                     -76.74                     -72.9
# 4          308080                     -83.41                    -71.82
